# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
##Write your code here

import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Select and clean relevant column
df_databases = df[['DatabaseWantToWorkWith']].dropna()

# Step 2: Split multiple selections into individual rows
df_databases['DatabaseWantToWorkWith'] = df_databases['DatabaseWantToWorkWith'].str.split(';')
df_exploded = df_databases.explode('DatabaseWantToWorkWith')

# Step 3: Clean whitespace
df_exploded['DatabaseWantToWorkWith'] = df_exploded['DatabaseWantToWorkWith'].str.strip()

# Step 4: Count frequency of each database
db_counts = df_exploded['DatabaseWantToWorkWith'].value_counts().nlargest(5)

# Step 5: Plot pie chart
plt.figure(figsize=(8, 6))
plt.pie(db_counts, labels=db_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Top 5 Databases Respondents Want to Work With')
plt.axis('equal')  # Equal aspect ratio ensures the pie is a circle.
plt.tight_layout()
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
##Write your code here

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
##Write your code here

import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Select the column and drop missing values
df_os = df[['OpSysProfessional use']].dropna()

# Step 2: Split multiple selections into individual rows
df_os['OpSysProfessional use'] = df_os['OpSysProfessional use'].str.split(';')
df_exploded = df_os.explode('OpSysProfessional use')

# Step 3: Clean whitespace
df_exploded['OpSysProfessional use'] = df_exploded['OpSysProfessional use'].str.strip()

# Step 4: Count operating system frequency
os_counts = df_exploded['OpSysProfessional use'].value_counts().nlargest(6)

# Step 5: Plot pie chart
plt.figure(figsize=(8, 6))
plt.pie(os_counts, labels=os_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Set3.colors)
plt.title('Top Operating Systems Used Professionally')
plt.axis('equal')  # Keeps pie chart circular
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
##Write your code here

import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Select and clean relevant column
df_lang = df[['LanguageHaveWorkedWith']].dropna()

# Step 2: Split multiple selections into individual rows
df_lang['LanguageHaveWorkedWith'] = df_lang['LanguageHaveWorkedWith'].str.split(';')
df_exploded = df_lang.explode('LanguageHaveWorkedWith')

# Step 3: Clean whitespace
df_exploded['LanguageHaveWorkedWith'] = df_exploded['LanguageHaveWorkedWith'].str.strip()

# Step 4: Count frequencies of each language
lang_counts = df_exploded['LanguageHaveWorkedWith'].value_counts().nlargest(5)

# Step 5: Plot pie chart
plt.figure(figsize=(8, 6))
plt.pie(lang_counts, labels=lang_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Pastel1.colors)
plt.title('Top 5 Programming Languages Respondents Have Worked With')
plt.axis('equal')  # Ensures pie is drawn as a circle
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
##Write your code here

import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Select and clean the relevant column
df_tools = df[['NEWCollabToolsHaveWorkedWith']].dropna()

# Step 2: Split multiple selections into individual rows
df_tools['NEWCollabToolsHaveWorkedWith'] = df_tools['NEWCollabToolsHaveWorkedWith'].str.split(';')
df_exploded = df_tools.explode('NEWCollabToolsHaveWorkedWith')

# Step 3: Clean whitespace
df_exploded['NEWCollabToolsHaveWorkedWith'] = df_exploded['NEWCollabToolsHaveWorkedWith'].str.strip()

# Step 4: Count frequency of each tool
tool_counts = df_exploded['NEWCollabToolsHaveWorkedWith'].value_counts().nlargest(5)

# Step 5: Plot pie chart
plt.figure(figsize=(8, 6))
plt.pie(
    tool_counts,
    labels=tool_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Set2.colors
)
plt.title('Top 5 Collaboration Tools Used Professionally')
plt.axis('equal')  # Keeps the pie chart circular
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
##Write your code here
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Select the relevant column and drop missing values
df_admired = df[['LanguageAdmired']].dropna()

# Step 2: Split multiple selections into individual rows
df_admired['LanguageAdmired'] = df_admired['LanguageAdmired'].str.split(';')
df_exploded = df_admired.explode('LanguageAdmired')

# Step 3: Clean whitespace
df_exploded['LanguageAdmired'] = df_exploded['LanguageAdmired'].str.strip()

# Step 4: Count frequency of each admired language
admired_counts = df_exploded['LanguageAdmired'].value_counts().nlargest(5)

# Step 5: Plot pie chart
plt.figure(figsize=(8, 6))
plt.pie(
    admired_counts,
    labels=admired_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Set3.colors
)
plt.title('Top 5 Most Admired Programming Languages')
plt.axis('equal')  # Keep the pie chart circular
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
##Write your code here
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Select and clean the relevant column
df_ai_tools = df[['AIToolCurrently Using']].dropna()

# Step 2: Split semicolon-separated tools into individual rows
df_ai_tools['AIToolCurrently Using'] = df_ai_tools['AIToolCurrently Using'].str.split(';')
df_exploded = df_ai_tools.explode('AIToolCurrently Using')

# Step 3: Strip whitespace from tool names
df_exploded['AIToolCurrently Using'] = df_exploded['AIToolCurrently Using'].str.strip()

# Step 4: Count occurrences of each tool
tool_counts = df_exploded['AIToolCurrently Using'].value_counts().nlargest(5)

# Step 5: Plot the pie chart
plt.figure(figsize=(8, 6))
plt.pie(
    tool_counts,
    labels=tool_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Set2.colors
)
plt.title('Top 5 AI Tools Currently Used by Developers')
plt.axis('equal')  # Ensures the pie chart is circular
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
##Write your code here

import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Select and clean the relevant column
df_web = df[['WebframeWantToWorkWith']].dropna()

# Step 2: Split semicolon-separated values into individual rows
df_web['WebframeWantToWorkWith'] = df_web['WebframeWantToWorkWith'].str.split(';')
df_exploded = df_web.explode('WebframeWantToWorkWith')

# Step 3: Remove leading/trailing whitespace
df_exploded['WebframeWantToWorkWith'] = df_exploded['WebframeWantToWorkWith'].str.strip()

# Step 4: Count the top 5 most wanted web frameworks
web_counts = df_exploded['WebframeWantToWorkWith'].value_counts().nlargest(5)

# Step 5: Create the pie chart
plt.figure(figsize=(8, 6))
plt.pie(
    web_counts,
    labels=web_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Pastel2.colors
)
plt.title('Top 5 Preferred Web Frameworks')
plt.axis('equal')  # Draw pie as a circle
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
##Write your code here
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Select and clean the relevant column
df_embedded = df[['EmbeddedWantToWorkWith']].dropna()

# Step 2: Split semicolon-separated entries into individual rows
df_embedded['EmbeddedWantToWorkWith'] = df_embedded['EmbeddedWantToWorkWith'].str.split(';')
df_exploded = df_embedded.explode('EmbeddedWantToWorkWith')

# Step 3: Strip whitespace from technology names
df_exploded['EmbeddedWantToWorkWith'] = df_exploded['EmbeddedWantToWorkWith'].str.strip()

# Step 4: Count the top 5 desired embedded technologies
embedded_counts = df_exploded['EmbeddedWantToWorkWith'].value_counts().nlargest(5)

# Step 5: Plot pie chart
plt.figure(figsize=(8, 6))
plt.pie(
    embedded_counts,
    labels=embedded_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Set3.colors
)
plt.title('Top 5 Most Desired Embedded Technologies')
plt.axis('equal')  # Keep the pie chart circular
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
